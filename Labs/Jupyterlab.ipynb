# %% [markdown]
# # Roger's Jupyter notebook

# %% [markdown]
# <font color='green'>*The purpose of this notebook is to get used to Jupyter notebook.*</font>

# %% [markdown]
# ### Table of Contents
#
# * [Name]
# * [Best_Holidays]
#     * [Where]
#     * [What to do]
#     * [Video]

# %% [markdown]
# ### Name <a class="anchor" id="chapter1"></a>
#
# ### Best_Holidays <a class="anchor" id="chapter1"></a>
#
# #### Where <a class="anchor" id="section_1_2_1"></a>
#
# #### What to do <a class="anchor" id="section_1_2_2"></a>
#
# #### Video <a class="anchor" id="section_1_2_3"></a>

# %%
name = input('What is your name?')
#user will be asked about his/her name

# %%
print('My name is',name)
# Out:
# My name is Roger

# %% [markdown]
# <div>
# <img src="attachment:foto_CV_RogerSerret.JPG" width="200"/>
# </div>

# %%
best_holidays = input('Where would you spend your holidays?')
#user will be asked about his/her favourite holidays

# %%
print('I would love to spend my holidays in', best_holidays)
# Out:
# I would love to spend my holidays in Philippines

# %% [markdown]
# ![pic_from_web](https://i.natgeofe.com/n/04505c35-858b-4e95-a1a7-d72e5418b7fc/steep-karst-cliffs-of-el-nido-in-palawan.jpg)

# %% [markdown]
# There you can:
#
# - See The Beauty Of The Banaue Rice Terraces
# - Go deep water soloing
# - Enjoy The Unusual Chocolate Hills

# %% [markdown]
# In this video you will see it better:

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('ZjFzkhrqIZs', width=800, height=300)
